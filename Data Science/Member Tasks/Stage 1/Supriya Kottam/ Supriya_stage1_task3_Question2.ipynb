# %% [markdown]
# ### Each student member creates notebooks to read the Enrichment data and displays them on a notebook.

# %%
#First we need to Load the data into a dataframe.

import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/Users/naramsupriya/Downloads/census.csv')

# Display the entire DataFrame
print(df.head())
# Out:
#    StateFIPS                  County Name,State     Total population  \
# 0          1  Baldwin County, Alabama!!Estimate              246,435
# 1          1  Calhoun County, Alabama!!Estimate              115,788
# 2          1  Cullman County, Alabama!!Estimate               90,665
# 3          1   DeKalb County, Alabama!!Estimate               71,998
# 4          1   Elmore County, Alabama!!Estimate               89,563
#
#           Male         Female          Sex ratio (males per 100 females)  \
# 0      120,664        125,771                                       95.9
# 1       56,554         59,234                                       95.5
# 2       45,051         45,614                                       98.8
# 3       36,024         35,974                                      100.1
# 4       43,448         46,115                                       94.2
#
#           Under 5 years         5 to 9 years         10 to 14 years  \
# ...

# %% [markdown]
# ### This is the changed file because the dataset originally did not had statefipsand also there was data regarding "ERRORS ,MARGIN OF ERRORS, PERCENTAGE , PERCENTAGE OF ERROR",in this stage we dont want this kind of data so i have downloaded the data with main columns and added "STATEFIPS"to merge with the supercovid data.And also i have transposed the table to be able to merge with the supercovid dataset i will display the original dataset without any deletions

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/Users/naramsupriya/Downloads/Census_original.csv')

# Display the entire DataFrame
print(df.head())
# Out:
#                             Label (Grouping)  \
# 0                                SEX AND AGE
# 1                           Total population
# 2                                       Male
# 3                                     Female
# 4          Sex ratio (males per 100 females)
#
#   Baldwin County, Alabama!!Estimate Baldwin County, Alabama!!Margin of Error  \
# 0                               NaN                                      NaN
# 1                           246,435                                    *****
# 2                           120,664                                   ±1,277
# 3                           125,771                                   ±1,277
# 4                              95.9                                     ±2.0
#
#   Baldwin County, Alabama!!Percent  \
# 0                              NaN
# 1                          246,435
# 2                            49.0%
# 3                            51.0%
# 4                              (X)
#
# ...

# %% [markdown]
# ## we will be using this data if we want to but for this stage  and better understanding i have made some changes.
